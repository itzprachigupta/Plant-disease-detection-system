# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os

import keras

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import img_to_array, load_img
from keras.applications.vgg19 import VGG19, preprocess_input, decode_predictions

# %%
#Exploratory Data Analysis
len(os.listdir("./TRAIN"))
# Out:
# 24

# %%
train_datagen = ImageDataGenerator(zoom_range=0.2, 
                                   shear_range= 0.3, 
                                   horizontal_flip= True, 
                                   preprocessing_function= preprocess_input)

train = train_datagen.flow_from_directory("./TRAIN", 
                                          target_size=(180,180), 
                                          batch_size=16)
# Out:
# Found 7040 images belonging to 24 classes.

# %%
train.class_indices
# Out:
# {'Anthurium_Bacterial_Blight': 0,
#  'Anthurium_Fresh_Leaf': 1,
#  'Anthurium_Leaf_Spot': 2,
#  'Gerbera_Fresh_Leaf': 3,
#  'Gerbera_Leaf_Blight': 4,
#  'Gerbera_Leaf_Spot': 5,
#  'Gerbera_Powdery_Mildew': 6,
#  'Gladiolus_Fresh_Leaf': 7,
#  'Gladiolus_Leaf_Spot': 8,
#  'Gladiolus_Rust': 9,
#  'Jasmine_Fresh_Leaf': 10,
#  'Jasmine_Leaf_Spot': 11,
#  'Marigold_Fresh_Leaf': 12,
#  'Marigold_Leaf_Spot': 13,
#  'Orchid_Black_Spot': 14,
#  'Orchid_Fresh_Leaf': 15,
#  'Orchid_Sun_Burn': 16,
#  'Orchid_Yellow_Leaf': 17,
#  'Rose_Black_Spot': 18,
#  'Rose_Downy_mildew': 19,
#  'Rose_Fresh_Leaf': 20,
#  'Tuberose_Fresh_Leaf': 21,
#  'Tuberose_Leaf_blight': 22,
#  'Tuberose_Leaf_spot': 23}

# %%
class_names = list(train.class_indices.keys())
class_names
# Out:
# ['Anthurium_Bacterial_Blight',
#  'Anthurium_Fresh_Leaf',
#  'Anthurium_Leaf_Spot',
#  'Gerbera_Fresh_Leaf',
#  'Gerbera_Leaf_Blight',
#  'Gerbera_Leaf_Spot',
#  'Gerbera_Powdery_Mildew',
#  'Gladiolus_Fresh_Leaf',
#  'Gladiolus_Leaf_Spot',
#  'Gladiolus_Rust',
#  'Jasmine_Fresh_Leaf',
#  'Jasmine_Leaf_Spot',
#  'Marigold_Fresh_Leaf',
#  'Marigold_Leaf_Spot',
#  'Orchid_Black_Spot',
#  'Orchid_Fresh_Leaf',
#  'Orchid_Sun_Burn',
#  'Orchid_Yellow_Leaf',
#  'Rose_Black_Spot',
#  'Rose_Downy_mildew',
#  'Rose_Fresh_Leaf',
#  'Tuberose_Fresh_Leaf',
#  'Tuberose_Leaf_blight',
#  'Tuberose_Leaf_spot']

# %%
count=0
for image_batch, label_batch in train:
    print(image_batch[0])
    break
# Out:
# [[[-58.577152   24.481987   -7.7952194]
#   [-41.09345    34.707314    3.2742157]
#   [-28.075027   42.246925   11.159294 ]
#   ...
#   [ 43.6381    108.36021    77.459206 ]
#   [ 35.479073   99.812416   68.911415 ]
#   [ 27.937752   91.88232    61.16326  ]]
#
#  [[-75.944496   12.88221   -19.299324 ]
#   [-58.794685   22.798485   -8.522202 ]
#   [-39.052963   37.302834    5.4270096]
#   ...
#   [ 16.378319   85.206474   53.571846 ]
#   [ 10.596748   79.424904   47.790276 ]
#   [  8.422913   77.25106    45.616432 ]]
#
#  [[-87.29868     7.630249  -24.212463 ]
#   [-76.75989    12.528175  -19.839378 ]
#   [-59.388027   24.333092   -8.159683 ]
#   ...
#   [ -8.876427   61.308556   29.407555 ]
#   [ -7.231552   63.574455   31.673454 ]
#   [ -1.8590546  68.9811     37.0801   ]]
#
#  ...
#
#  [[122.88772   133.78934   116.24148  ]
#   [121.36193   131.21799   111.50797  ]
#   [118.07543   124.608086  107.63737  ]
#   ...
#   [143.6666    132.8266    125.92559  ]
#   [140.96371   130.12372   123.22271  ]
#   [139.53186   128.69186   121.790855 ]]
#
#  [[116.534584  135.4932    114.510704 ]
#   [109.71433   128.00021   105.462975 ]
#   [103.80912   117.52953    97.731575 ]
#   ...
#   [141.89795   131.05795   124.156944 ]
#   [139.69153   128.85153   121.95054  ]
#   [139.37961   128.53961   121.63862  ]]
#
#  [[100.889015  129.08444   104.433586 ]
#   [ 94.82371   122.68453    96.64413  ]
#   [ 91.813286  115.30303    91.418755 ]
#   ...
#   [140.13364   129.44507   122.49358  ]
#   [138.07034   127.66209   120.617165 ]
#   [138.38766   127.8101    120.82162  ]]]

# %%
val_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)

val = val_datagen.flow_from_directory(directory= "./VALID", 
                                          target_size=(180,180), 
                                          batch_size=16 )
# Out:
# Found 1931 images belonging to 24 classes.

# %%
val.class_indices
# Out:
# {'Anthurium_Bacterial_Blight': 0,
#  'Anthurium_Fresh_Leaf': 1,
#  'Anthurium_Leaf_Spot': 2,
#  'Gerbera_Fresh_Leaf': 3,
#  'Gerbera_Leaf_Blight': 4,
#  'Gerbera_Leaf_Spot': 5,
#  'Gerbera_Powdery_Mildew': 6,
#  'Gladiolus_Fresh_Leaf': 7,
#  'Gladiolus_Leaf_Spot': 8,
#  'Gladiolus_Rust': 9,
#  'Jasmine_Fresh_Leaf': 10,
#  'Jasmine_Leaf_Spot': 11,
#  'Marigold_Fresh_Leaf': 12,
#  'Marigold_Leaf_Spot': 13,
#  'Orchid_Black_Spot': 14,
#  'Orchid_Fresh_Leaf': 15,
#  'Orchid_Sun_Burn': 16,
#  'Orchid_Yellow_Leaf': 17,
#  'Rose_Black_Spot': 18,
#  'Rose_Downy_Mildew': 19,
#  'Rose_Fresh_Leaf': 20,
#  'Tuberose_Fresh_Leaf': 21,
#  'Tuberose_Leaf_blight': 22,
#  'Tuberose_Leaf_spot': 23}

# %%
t_img, label = train.next()

# %%
t_img.shape
# Out:
# (16, 180, 180, 3)

# %%
def plotImage(img_arr,label):
    
    for im, l in zip(img_arr, label):
        plt.figure(figsize=(3,3))
        plt.imshow(im/179)
        plt.show()
plotImage(t_img[:3], label[:3])
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
test_datagen = ImageDataGenerator(
        zoom_range=0.2, 
        shear_range= 0.3, 
        horizontal_flip=True,
        preprocessing_function= preprocess_input)

test = test_datagen.flow_from_directory(
        './TEST',
        target_size=(180,180),
        batch_size=16
)
# Out:
# Found 4687 images belonging to 24 classes.

# %%
for image_batch, label_batch in test:
    print(image_batch[0])
    break
# Out:
# [[[ -92.66557  -116.779    -119.85972 ]
#   [ -92.66557  -116.779    -119.85972 ]
#   [ -92.66557  -116.779    -119.85972 ]
#   ...
#   [-101.66557  -110.69299  -122.40657 ]
#   [-101.66557  -110.69299  -122.40657 ]
#   [-101.66557  -110.69299  -122.40657 ]]
#
#  [[ -97.88997  -116.779    -116.43631 ]
#   [ -97.88997  -116.779    -116.43631 ]
#   [ -97.88997  -116.779    -116.43631 ]
#   ...
#   [-102.646286 -110.90084  -123.38728 ]
#   [-102.646286 -110.90084  -123.38728 ]
#   [-102.646286 -110.90084  -123.38728 ]]
#
#  [[ -99.251015 -116.779    -114.68    ]
#   [ -99.251015 -116.779    -114.68    ]
#   [ -99.251015 -116.779    -114.68    ]
#   ...
#   [-101.56303  -115.21895  -123.68    ]
#   [-101.56303  -115.21895  -123.68    ]
#   [-101.56303  -115.21895  -123.68    ]]
#
#  ...
#
#  [[-103.939    -114.46699  -122.43196 ]
#   [-103.939    -114.46699  -122.43196 ]
#   [-103.939    -114.46699  -122.43196 ]
#   ...
#   [-103.31498  -106.84297  -114.99201 ]
#   [-103.31498  -106.84297  -114.99201 ]
#   [-103.31498  -106.84297  -114.99201 ]]
#
#  [[-103.939    -112.90084  -118.80184 ]
#   [-103.939    -112.90084  -118.80184 ]
#   [-103.939    -112.90084  -118.80184 ]
#   ...
#   [-101.060844 -106.24259  -116.55816 ]
#   [-101.060844 -106.24259  -116.55816 ]
#   [-101.060844 -106.24259  -116.55816 ]]
#
#  [[-103.66557  -111.32585  -117.77371 ]
#   [-103.66557  -111.32585  -117.77371 ]
#   [-103.66557  -111.32585  -117.77371 ]
#   ...
#   [ -98.939    -110.32585  -120.047134]
#   [ -98.939    -110.32585  -120.047134]
#   [ -98.939    -110.32585  -120.047134]]]

# %% [markdown]
# # Building our Model

# %%
from keras.layers import Dense, Flatten
from keras.models import Model
from keras.applications.vgg19 import VGG19
import keras

# %%
base_model = VGG19(input_shape=(180,180,3), include_top = False)

# %%
for layer in base_model.layers:
    layer.trainable = False

# %%
base_model.summary()
# Out:
# Model: "vgg19"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 180, 180, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 180, 180, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 180, 180, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 90, 90, 64)        0
#
#  block2_conv1 (Conv2D)       (None, 90, 90, 128)       73856
#
#  block2_conv2 (Conv2D)       (None, 90, 90, 128)       147584
#
#  block2_pool (MaxPooling2D)  (None, 45, 45, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 45, 45, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 45, 45, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 45, 45, 256)       590080
#
#  block3_conv4 (Conv2D)       (None, 45, 45, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 22, 22, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 22, 22, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 22, 22, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 22, 22, 512)       2359808
#
#  block4_conv4 (Conv2D)       (None, 22, 22, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 11, 11, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 11, 11, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 11, 11, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 11, 11, 512)       2359808
#
#  block5_conv4 (Conv2D)       (None, 11, 11, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 5, 5, 512)         0
#
# =================================================================
# Total params: 20,024,384
# Trainable params: 0
# Non-trainable params: 20,024,384
# _________________________________________________________________

# %%
X= Flatten()(base_model.output)

X = Dense(units= 24, activation='softmax')(X)

#Creating our Model
model = Model(base_model.input, X)

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 180, 180, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 180, 180, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 180, 180, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 90, 90, 64)        0
#
#  block2_conv1 (Conv2D)       (None, 90, 90, 128)       73856
#
#  block2_conv2 (Conv2D)       (None, 90, 90, 128)       147584
#
#  block2_pool (MaxPooling2D)  (None, 45, 45, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 45, 45, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 45, 45, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 45, 45, 256)       590080
#
#  block3_conv4 (Conv2D)       (None, 45, 45, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 22, 22, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 22, 22, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 22, 22, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 22, 22, 512)       2359808
#
#  block4_conv4 (Conv2D)       (None, 22, 22, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 11, 11, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 11, 11, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 11, 11, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 11, 11, 512)       2359808
#
#  block5_conv4 (Conv2D)       (None, 11, 11, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 5, 5, 512)         0
#
#  flatten (Flatten)           (None, 12800)             0
#
#  dense (Dense)               (None, 24)                307224
#
# =================================================================
# Total params: 20,331,608
# Trainable params: 307,224
# Non-trainable params: 20,024,384
# _________________________________________________________________

# %%
model.compile(optimizer='adam', 
              loss= keras.losses.categorical_crossentropy, 
              metrics=['accuracy'])

# %% [markdown]
# # Early stopping and Model Check point

# %%
from keras.callbacks import ModelCheckpoint, EarlyStopping

#early stopping
es = EarlyStopping(monitor = 'val_accuracy', min_delta=0.01, patience=3, verbose=1)

#model check point
mc = ModelCheckpoint(filepath="best_model.h5",
                     monitor='val_accuracy',
                     min_delta= 0.01,
                     patience= 3,
                     verbose=1,
                     save_best_only=True)

cb = [es,mc]

# %%
history = model.fit(
    train, 
    steps_per_epoch=16, 
    epochs=30, 
    verbose=1, 
    callback=cb,
    batch_size=16,
    validation_data= val,
    validation_steps= 16)

# %%
model.save('./final_model.h5')

# %%
scores = model.evaluate(test)

# %%
scores

# %% [markdown]
# # Plotting the accuracy and loss curve

# %%
history
history.params
history.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
type(history.history['loss'])
len(history.history['loss'])
# Out:
# 10

# %%
history.history['loss'][:5] # show loss for first 5 epochs
# Out:
# [14.027483940124512,
#  9.124931335449219,
#  5.799154281616211,
#  3.8710618019104004,
#  3.5812556743621826]

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

# %%
acc
# Out:
# [0.25390625,
#  0.47265625,
#  0.58203125,
#  0.69921875,
#  0.75,
#  0.71484375,
#  0.734375,
#  0.79296875,
#  0.765625,
#  0.796875]

# %%
val_acc
# Out:
# [0.3671875,
#  0.4921875,
#  0.57421875,
#  0.59765625,
#  0.65625,
#  0.671875,
#  0.76171875,
#  0.703125,
#  0.65234375,
#  0.6953125]

# %%
loss
# Out:
# [14.027483940124512,
#  9.124931335449219,
#  5.799154281616211,
#  3.8710618019104004,
#  3.5812556743621826,
#  4.050449371337891,
#  4.478890895843506,
#  2.469616651535034,
#  2.573354959487915,
#  2.590700149536133]

# %%
val_loss
# Out:
# [14.13052749633789,
#  8.132854461669922,
#  6.80364465713501,
#  7.106279373168945,
#  5.722868919372559,
#  5.4147725105285645,
#  3.6831839084625244,
#  5.785660266876221,
#  6.467936038970947,
#  5.569188117980957]

# %%
# Prediction scores
test.reset()
predictions = model.predict(test)
predicted_classes = np.argmax(predictions, axis=1)

# %%
# Accuracy score
test_loss, test_accuracy = model.evaluate(test, verbose=2)
print("Test Accuracy:", test_accuracy)

# %%
# Confusion matrix
from sklearn.metrics import precision_recall_fscore_support
true_classes = test.classes
class_labels = list(test.class_indices.keys())
confusion_mtx = confusion_matrix(true_classes, predicted_classes)
precision, recall, fscore, _ = precision_recall_fscore_support(true_classes, predicted_classes, average='weighted')
print("Confusion Matrix:\n", confusion_mtx)
print("Precision:", precision)
print("Recall:", recall)
print("F1 Score:", fscore)

# %%
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 2)
plt.plot(h['accuracy'])
plt.plot(h['val_accuracy'], c='red')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title("Training Accuracy vs Validation Accuracy")
plt.legend()

plt.tight_layout()
plt.show()

# %%
# plt.plot(h['loss'])
# plt.plot(h['val_loss'], c='red')
# plt.title("Loss vs Validation Loss")
# plt.show()

plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 2)
plt.plot(h['loss'])
plt.plot(h['val_loss'], c='red')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title("Training Loss vs Validation Loss")
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# # Run prediction on a sample image

# %%
# #load best model

# from keras.models import load_model
# model = load_model('./best_model.h5')

# load the saved model
import numpy as np
from tensorflow import keras
from tensorflow.keras.preprocessing import image

model = keras.models.load_model('./final_model.h5')

# %%
import numpy as np

for image_batch, label_batch in test:
    first_image = image_batch[0]
    first_label = int(label_batch[0])
    
    print("first image to predict")
    plt.imshow(first_image)
    print("actual label:",class_names[first_label])
    
    batch_prediction = model.predict(image_batch)
    print("predicted label:",class_names[np.argmax(batch_prediction[0])])
    
    break

# %% [markdown]
# # function for inference

# %%
def predict(model, img):
    img_array = tf.keras.preprocessing.image.img_to_array(images[i])
    img_array = tf.expand_dims(img_array, 0)

    predictions = model.predict(img_array)

    predicted_class = class_names[np.argmax(predictions[0])]
    confidence = round(100 * (np.max(predictions[0])), 2)
    return predicted_class, confidence

# %%
plt.figure(figsize=(12, 12))
for images, labels in test_generator:
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i])
        
        predicted_class, confidence = predict(model, images[i])
        actual_class = class_names[int(labels[i])] 
        
        plt.title(f"Actual: {actual_class},\n Predicted: {predicted_class},\n Confindence:{confidence}.")
        
        plt.axis("off")
    break

# %%
acc = model.evaluate_generator(test)[1]
print(f"The accuracy of your model is= {acc*100}%")
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_3308\3913275857.py:1: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   acc = model.evaluate_generator(val)[1]
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x000001E8CFADCFE0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Constant'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x000001E8CFADCFE0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Constant'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# The accuracy of your model is= 72.39772081375122%

# %%
ref = dict(zip(list(train.class_indices.values()), list(train.class_indices.keys())))

# %%
def prediction(path):
    img = load_img(path, target_size= (180,180))
    i = img_to_array(img)
    im = preprocess_input(i)
    img = np.expand_dim(im, axis=0)
    pred= np.argmax(model.predict(im))
    print(f"The image belongs to {ref(pred)} ")

# %%
path = './TEST/Gerbera_Fresh_Leaf/Gerbera_Fresh_Leaf (1).jpg'
prediction(path)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[48], line 2
#       1 path = './VALID/Gerbera_Fresh_Leaf/Gerbera_Fresh_Leaf (1).jpg'
# ----> 2 prediction(path)
#
# Cell In[47], line 5, in prediction(path)
#       3 i = img_to_array(img)
#       4 im = preprocess_input(i)
# ----> 5 img = np.expand_dim(im, axis=0)
#       6 pred= np.argmax(model.predict(im))
#       7 print(f"The image belongs to {ref(pred)} ")
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\numpy\__init__.py:311, in __getattr__(attr)
#     308     from .testing import Tester
#     309     return Tester
# --> 311 raise AttributeError("module {!r} has no attribute "
#     312                      "{!r}".format(__name__, attr))
#
# AttributeError: module 'numpy' has no attribute 'expand_dim'
